# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drbob-richardson/stat220/blob/main/Assignments/Stat_220_HW1.ipynb)

# %% [markdown]
# **Problem 1**. Give an example of a variable that is (a) categorical; (b) quantitative; (c) discrete; (d) continuous.

# %% [markdown]
# a. Colors of people's shirts
# b. Number of people in the World
# c. number of Baby's being born
# d. Height

# %% [markdown]
# **Problem 2**. Analyze the Carbon_West data file using the following code.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
carbon_west = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Carbon_West.dat")

# %% [markdown]
# Part a. Construct a histogram of CO2 emissions.

# %%
carbon_west
# Out:
#          Nation   CO2
# 0       Albania   2.0
# 1     Australia  15.4
# 2       Austria   6.9
# 3       Belgium   8.3
# 4        Bosnia   6.2
# 5      Bulgaria   5.9
# 6        Canada  15.1
# 7       Croatia   4.0
# 8        Cyprus   5.3
# 9         Czech   9.2
# 10      Denmark   5.9
# 11      Finland   8.7
# 12       France   4.6
# 13      Germany   8.9
# 14       Greece   6.2
# 15      Hungary   4.3
# 16      Ireland   7.3
# 17        Italy   5.3
# 18       Latvia   3.5
# 19    Lithuania   4.4
# 20        Malta   5.4
# 21   Montenegro   3.6
# 22  Netherlands   9.9
# 23   NewZealand   7.7
# 24       Norway   9.3
# 25     Portugal   4.3
# 26      Romania   3.5
# 27       Serbia   5.3
# 28       Slovak   5.7
# 29     Slovenia   6.2
# 30        Spain   5.0
# 31       Sweden   4.5
# 32  Switzerland   4.3
# 33           UK   6.5
# 34           US  16.5

# %%
x = carbon_west['Nation']
y = carbon_west['CO2']

# %%
plt.hist(carbon_west["CO2"], bins=15, edgecolor='black')
plt.title(f'Histogram of CO2')
plt.xlabel("Amount of CO2")
plt.ylabel('Number of Nations')
plt.show()

# %% [markdown]
# Part b. Find the mean, median, and standard deviation.

# %%
mean_value = np.mean(carbon_west["CO2"])
median_value = np.median(carbon_west["CO2"])
std_deviation = np.std(carbon_west["CO2"])
variance = np.var(carbon_west["CO2"])

print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Standard Deviation: {std_deviation}")
print(f"Variance: {variance}")
# Out:
# Mean: 6.717142857142858
# Median: 5.9
# Standard Deviation: 3.3086454469884727
# Variance: 10.94713469387755

# %% [markdown]
# **Problem 3**. Read in the murder data set using the following code. The variable murder is the murder rate (per 100,000 population) for each state in the U.S. in 2017 according to the FBI Uniform Crime Reports. At first, do not use the observation for D.C. (DC).

# %%
murders = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Murder.dat")

# %%
murders.head()
# Out:
#   state  murder
# 0    AK     8.4
# 1    AL     8.3
# 2    AR     8.6
# 3    AZ     5.9
# 4    CA     4.6

# %% [markdown]
# Part a. Find the mean and standard deviation for murders without D.C.

# %%
murders_wo_DC = murders.loc[murders['state'] != 'DC']

# %%
mean = np.mean(murders_wo_DC['murder'])
std = np.std(murders_wo_DC['murder'])

print(f'Mean = {mean}')
print(f'Standard Deveation = {std}')
# Out:
# Mean = 4.874
# Standard Deveation = 2.560297638947472

# %% [markdown]
# Part b. Find the five-number  summary without D.C.

# %%
minimum = np.min(murders_wo_DC['murder'])
q1 = np.percentile(murders_wo_DC["murder"], 25)
median = np.median(murders_wo_DC["murder"])
q3 = np.percentile(murders_wo_DC["murder"], 75)
maximum = np.max(murders_wo_DC["murder"])

print(f"Minimum: {minimum}")
print(f"1st Quartile (Q1): {q1}")
print(f"Median (Q2): {median}")
print(f"3rd Quartile (Q3): {q3}")
print(f"Maximum: {maximum}")
# Out:
# Minimum: 1.0
# 1st Quartile (Q1): 2.625
# Median (Q2): 4.85
# 3rd Quartile (Q3): 6.175
# Maximum: 12.4

# %% [markdown]
# Part c. Now include the observation for D.C. and recalculate the mean, median, and five-number summary. What is affected more by this outlier: The mean or the median? The range or the inter-quartile range?

# %%
mean = np.mean(murders['murder'])
std = np.std(murders['murder'])
minimum = np.min(murders['murder'])
q1 = np.percentile(murders["murder"], 25)
median = np.median(murders["murder"])
q3 = np.percentile(murders["murder"], 75)
maximum = np.max(murders["murder"])

print(f'Mean = {mean}')
print(f'Standard Deveation = {std}')
print(f"Minimum: {minimum}")
print(f"1st Quartile (Q1): {q1}")
print(f"Median (Q2): {median}")
print(f"3rd Quartile (Q3): {q3}")
print(f"Maximum: {maximum}")
# Out:
# Mean = 5.252941176470588
# Standard Deveation = 3.688687153732127
# Minimum: 1.0
# 1st Quartile (Q1): 2.6500000000000004
# Median (Q2): 5.0
# 3rd Quartile (Q3): 6.45
# Maximum: 24.2

# %% [markdown]
# **Problem 4**. Read in the Houses data file using the following code.  The variables include price (thousands of dollars), size (square feet), tax bill (dollars), number of bathrooms, number of bedrooms, and whether the house is new (1 = yes, 0 = no) for 100 home sales in Gainesville, Florida. Let
# y = selling price and x = size of home.

# %%
houses = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Houses.dat")

# %%
houses.head()
# Out:
#    case   price  size  new  taxes  bedrooms  baths
# 0     1  419.85  2048    0   3104         4      2
# 1     2  219.75   912    0   1173         2      1
# 2     3  356.55  1654    0   3076         4      2
# 3     4  300.00  2068    0   1608         3      2
# 4     5  239.85  1477    0   1454         3      3

# %% [markdown]
# Part a. Construct a scatterplot between square feet and price of a home.

# %%
plt.figure(figsize=(6, 4))
plt.scatter(houses['price'], houses['size'], alpha=0.7)
plt.title('Scatter Plot: Price vs. Square Feet')
plt.xlabel('Price')
plt.ylabel('Square Feet')

plt.show()

# %% [markdown]
# Part b. Find the correlation between the two variables.

# %%
correlation = houses['price'].corr(houses['size'])

print(f'Correlation between Entry and Time: {correlation}')
# Out:
# Correlation between Entry and Time: 0.8337847885586538

# %% [markdown]
# Part c. Find and plot the regression line on top of the scatterplot.

# %%
x = houses[['price']]
y = houses['size']

model = LinearRegression()

model.fit(x, y)

slope = model.coef_[0]
intercept = model.intercept_

print(f'Slope (Coefficient): {slope}')
print(f'Intercept: {intercept}')
# Out:
# Slope (Coefficient): 3.661029004980169
# Intercept: 776.2730554411382

# %%
# Plot the scatterplot
plt.figure(figsize=(6, 4))
plt.scatter(x, y, alpha=0.7, label='Scatterplot')

# Plot the regression line
plt.plot(x, model.predict(x), color='red', label='Regression Line')

plt.title('Scatter Plot with Regression Line')
plt.xlabel('Price')
plt.ylabel('Size')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Part d. Create a side by side boxplot of price comparing homes that are new and homes that are not new.

# %%
plt.figure(figsize=(8, 6))
houses.boxplot(column='price', by='new', vert=False,grid = False)
plt.title('Side-by-Side Box Plot of Price by New or Old')
plt.xlabel('Price')
plt.ylabel('New')
plt.show()

# %% [markdown]
# Part e. What is the relationship between size and price.  Justify your answer using the plots created. Do the same for the relationship between price and whether or not a house is new, again using the plot to justify your answer.

# %% [markdown]
# There appears to be some correlation between size and price. This is evident by the trend line present in the graph. The larger the house, the higher the price and vice versa. The correlation is also a positive one as the slope is increasing in the trend line. From the box plot it seems that the older houses have a lower price than newer ones. You can see this because the mean line in the box plot of older house than new ones. The box itself is also at a lower price range in the older box than the newer houses.

# %% [markdown]
# **Problem 1.22**. Using the Happy data file read in by the following code. Construct the contingency table relating marital status and happiness.

# %%
happy = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Happy.dat")

# %%
happy
# Out:
#       subject happiness marital gender
# 0           1   1     1    male    NaN
# 1           2   1     1    male    NaN
# 2           3   1     1    male    NaN
# 3           4   1     1    male    NaN
# 4           5   1     1    male    NaN
# ...       ...       ...     ...    ...
# 2137     2138         3      fe    ale
# 2138     2139         3      fe    ale
# 2139     2140         3      fe    ale
# 2140     2141         3      fe    ale
# 2141     2142         3      fe    ale
#
# [2142 rows x 4 columns]

# %%
pd.crosstab(happy['marital'],happy["happiness"])
# Out:
# happiness    1  1     1  1     2  1     3    2  2     1  2     2  2     3  \
# marital
# fe         348        0        0        0  642        0        0        0
# fem          0        5        0        0    0        0        0        0
# mal          0      107       33       56    0      229      114      210
# male         0       99        0        0    0        0        0        0
#
# happiness    3  3     1  3     2  3     3
# marital
# fe         153        0        0        0
# fem          0        0        0        0
# mal          0       33       45       68
# male         0        0        0        0
